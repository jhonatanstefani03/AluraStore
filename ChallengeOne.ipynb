# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %%
loja2.head()
# Out:
#                  Produto   Categoria do Produto    Preço      Frete  \
# 0  Cadeira de escritório                 moveis   378.20  20.421138
# 1               Pandeiro  instrumentos musicais   102.37   3.035334
# 2              Cama king                 moveis   591.13  31.759020
# 3              Cama king                 moveis  1208.24  61.919584
# 4  Cadeira de escritório                 moveis   530.41  25.827176
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     04/08/2021    Thiago Silva              MG                    1
# 1     26/11/2020   Bianca Santos              RJ                    3
# 2     22/10/2021    Thiago Silva              SC                    5
# 3     04/05/2022   Larissa Alves              RS                    5
# 4     26/02/2022  Lucas Oliveira              SP                    4
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0            boleto                       1 -18.10 -44.38
# ...

# %%
loja3.head()
# Out:
#               Produto   Categoria do Produto    Preço      Frete  \
# 0  Secadora de roupas       eletrodomesticos  1713.50  88.823159
# 1              Cômoda                 moveis   386.81  18.180908
# 2              Violão  instrumentos musicais   404.62  23.197592
# 3       Bola de vôlei        esporte e lazer    78.40   4.463341
# 4       Guarda roupas                 moveis   694.76  34.578319
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     17/12/2021  Camila Ribeiro              CE                    4
# 1     10/02/2021   Larissa Alves              RS                    3
# 2     22/01/2023  Lucas Oliveira              SP                    5
# 3     22/03/2022     Pedro Gomes              BA                    4
# 4     12/01/2022   Bianca Santos              SP                    1
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       4  -5.20 -39.53
# ...

# %%
loja4.head()
# Out:
#                Produto Categoria do Produto    Preço      Frete  \
# 0          Lava louças     eletrodomesticos  1446.46  74.604083
# 1             Cama box               moveis   631.70  33.919251
# 2     Bola de basquete      esporte e lazer    31.54   0.000000
# 3  Modelagem preditiva               livros    76.93   1.680730
# 4       Fone de ouvido          eletronicos   185.14   7.442587
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     11/11/2022    Rafael Costa              SP                    4
# 1     03/01/2020    Thiago Silva              GO                    5
# 2     25/12/2022   Larissa Alves              MG                    5
# 3     23/11/2021  Lucas Oliveira              MG                    3
# 4     25/04/2022   Bianca Santos              SP                    4
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       3 -22.19 -48.79
# ...

# %% [markdown]
# ## 1. Análise do **faturamento**

# %%
faturametento_total = loja['Preço'].sum()
faturametento_total
f"R$ {loja['Preço'].sum():.2f}"
# Out:
# 'R$ 1534509.12'

# %%
faturametento_total2 = loja2['Preço'].sum()
faturametento_total2
f"R$ {loja2['Preço'].sum():.2f}"
# Out:
# 'R$ 1488459.06'

# %%
faturametento_total3 = loja3['Preço'].sum()
faturametento_total3
f"R$ {loja3['Preço'].sum():.2f}"
# Out:
# 'R$ 1464025.03'

# %%
faturametento_total4 = loja4['Preço'].sum()
faturametento_total4
f"R$ {loja4['Preço'].sum():.2f}"
# Out:
# 'R$ 1384497.58'

# %%
faturamento = {'loja 1': faturametento_total,
               'loja 2': faturametento_total2,
               'loja 3': faturametento_total3,
               'loja 4': faturametento_total4}
lojas_faturamento = pd.DataFrame(list(faturamento.items()), columns=['Loja', 'Faturamento'])
lojas_faturamento.plot(x='Loja', y='Faturamento',xlabel='faturamento', ylabel='lojas',kind='barh', figsize=(5,5), color='green');

# %% [markdown]
# ## 2. Vendas por Categoria

# %%
vendas_por_categoria = loja['Categoria do Produto'].value_counts()
vendas_por_categoria
# Out:
# Categoria do Produto
# moveis                   465
# eletronicos              448
# brinquedos               324
# eletrodomesticos         312
# esporte e lazer          284
# instrumentos musicais    182
# livros                   173
# utilidades domesticas    171
# Name: count, dtype: int64

# %%
vendas_por_categoria2 = loja2['Categoria do Produto'].value_counts()
vendas_por_categoria2
# Out:
# Categoria do Produto
# moveis                   442
# eletronicos              422
# brinquedos               313
# eletrodomesticos         305
# esporte e lazer          275
# instrumentos musicais    224
# livros                   197
# utilidades domesticas    181
# Name: count, dtype: int64

# %%
vendas_por_categoria3 = loja3['Categoria do Produto'].value_counts()
vendas_por_categoria3
# Out:
# Categoria do Produto
# moveis                   499
# eletronicos              451
# brinquedos               315
# eletrodomesticos         278
# esporte e lazer          277
# livros                   185
# instrumentos musicais    177
# utilidades domesticas    177
# Name: count, dtype: int64

# %%
vendas_por_categoria4 = loja4['Categoria do Produto'].value_counts()
vendas_por_categoria4
# Out:
# Categoria do Produto
# moveis                   480
# eletronicos              451
# brinquedos               338
# esporte e lazer          277
# eletrodomesticos         254
# utilidades domesticas    201
# livros                   187
# instrumentos musicais    170
# Name: count, dtype: int64

# %%
total_vendas = vendas_por_categoria2 + vendas_por_categoria3 + vendas_por_categoria4 +vendas_por_categoria
total_vendas.sort_values()
# Out:
# Categoria do Produto
# utilidades domesticas     730
# livros                    742
# instrumentos musicais     753
# esporte e lazer          1113
# eletrodomesticos         1149
# brinquedos               1290
# eletronicos              1772
# moveis                   1886
# Name: count, dtype: int64

# %% [markdown]
# ##3. Média de Avaliação das Lojas

# %%
loja['Avaliação da compra'].mean().round(2)
# Out:
# np.float64(3.98)

# %%
media = sum(loja2['Avaliação da compra']) / len(loja2['Avaliação da compra'])
media
# Out:
# 4.037303942348453

# %%
media = sum(loja3['Avaliação da compra']) / len(loja3['Avaliação da compra'])

# %%
media = sum(loja4['Avaliação da compra']) / len(loja4['Avaliação da compra'])
media
# Out:
# 3.9957591178965224

# %%
import matplotlib.pyplot as plt

# Cálculo das médias
media1 = loja['Avaliação da compra'].mean()
media2 = loja2['Avaliação da compra'].mean()
media3 = loja3['Avaliação da compra'].mean()
media4 = loja4['Avaliação da compra'].mean()

# Criar DataFrame com as médias
df_medias = pd.DataFrame({
    'Loja': ['loja', 'loja2', 'loja3', 'loja4'],
    'Média Avaliação': [media1, media2, media3, media4]
})

# Gráfico de linha
plt.figure(figsize=(8,5))
plt.plot(df_medias['Loja'], df_medias['Média Avaliação'], marker='o')
plt.title('Média de Avaliação por Loja')
plt.xlabel('Lojas')
plt.ylabel('Média das Avaliações')
plt.grid(True)
plt.show()

# %% [markdown]
# ##4. Produtos Mais e Menos Vendidos

# %% [markdown]
# loja 1

# %%
produtos_por_venda = loja.groupby(['Produto', 'Categoria do Produto'])['Produto'].count().sort_values(ascending=False)
mais_vendido=produtos_por_venda.head(5)
mais_vendido
# Out:
# Produto             Categoria do Produto
# TV Led UHD 4K       eletronicos             60
# Micro-ondas         eletrodomesticos        60
# Guarda roupas       moveis                  60
# Secadora de roupas  eletrodomesticos        58
# Blocos de montar    brinquedos              56
# Name: Produto, dtype: int64

# %%
produtos_por_venda = loja.groupby(['Produto', 'Categoria do Produto'])['Produto'].count().sort_values(ascending=False)
menos_vendido = produtos_por_venda.tail(5)
menos_vendido
# Out:
# Produto                      Categoria do Produto
# Ciência de dados com python  livros                   39
# Pandeiro                     instrumentos musicais    36
# Panela de pressão            utilidades domesticas    35
# Celular ABXY                 eletronicos              33
# Headset                      eletronicos              33
# Name: Produto, dtype: int64

# %% [markdown]
# loja 2

# %%
produtos_por_venda = loja2.groupby(['Produto', 'Categoria do Produto'])['Produto'].count().sort_values(ascending=False)
mais_vendido=produtos_por_venda.head(5)
mais_vendido
# Out:
# Produto                   Categoria do Produto
# Iniciando em programação  livros                   65
# Micro-ondas               eletrodomesticos         62
# Bateria                   instrumentos musicais    61
# Violão                    instrumentos musicais    58
# Pandeiro                  instrumentos musicais    58
# Name: Produto, dtype: int64

# %%
produtos_por_venda = loja2.groupby(['Produto', 'Categoria do Produto'])['Produto'].count().sort_values(ascending=False)
menos_vendido = produtos_por_venda.tail(5)
menos_vendido
# Out:
# Produto            Categoria do Produto
# Fone de ouvido     eletronicos             37
# Poltrona           moveis                  35
# Impressora         eletronicos             34
# Mesa de jantar     moveis                  34
# Jogo de tabuleiro  brinquedos              32
# Name: Produto, dtype: int64

# %% [markdown]
# loja 3

# %%
produtos_por_venda = loja3.groupby(['Produto', 'Categoria do Produto'])['Produto'].count().sort_values(ascending=False)
mais_vendido=produtos_por_venda.head(5)

mais_vendido
# Out:
# Produto          Categoria do Produto
# Kit banquetas    moveis                   57
# Mesa de jantar   moveis                   56
# Cama king        moveis                   56
# Cômoda           moveis                   55
# Jogo de panelas  utilidades domesticas    55
# Name: Produto, dtype: int64

# %%
produtos_por_venda = loja3.groupby(['Produto', 'Categoria do Produto'])['Produto'].count().sort_values(ascending=False)
menos_vendido = produtos_por_venda.tail(5)
menos_vendido
# Out:
# Produto           Categoria do Produto
# Copo térmico      esporte e lazer          38
# Micro-ondas       eletrodomesticos         36
# Jogo de copos     utilidades domesticas    36
# Mochila           esporte e lazer          36
# Blocos de montar  brinquedos               35
# Name: Produto, dtype: int64

# %% [markdown]
# loja 4

# %%
produtos_por_venda = loja4.groupby(['Produto', 'Categoria do Produto'])['Produto'].count().sort_values(ascending=False)
mais_vendido=produtos_por_venda.head(5)
mais_vendido
# Out:
# Produto                  Categoria do Produto
# Cama box                 moveis                   62
# Faqueiro                 utilidades domesticas    59
# Cama king                moveis                   56
# Dashboards com Power BI  livros                   56
# Cômoda                   moveis                   55
# Name: Produto, dtype: int64

# %%
produtos_por_venda = loja4.groupby(['Produto', 'Categoria do Produto'])['Produto'].count().sort_values(ascending=False)
menos_vendido = produtos_por_venda.tail(5)
menos_vendido
# Out:
# Produto             Categoria do Produto
# Geladeira           eletrodomesticos         38
# Lavadora de roupas  eletrodomesticos         38
# Violão              instrumentos musicais    37
# Guarda roupas       moveis                   34
# Guitarra            instrumentos musicais    33
# Name: Produto, dtype: int64

# %% [markdown]
# Total lojas

# %%
todas_lojas = pd.concat([loja, loja2, loja3, loja4])
produtos_por_venda = todas_lojas.groupby(['Produto', 'Categoria do Produto'])['Produto'].count().sort_values(ascending=False)
produtos_por_venda.head(5)
# Out:
# Produto                   Categoria do Produto
# Cômoda                    moveis                   210
# Carrinho controle remoto  brinquedos               206
# Micro-ondas               eletrodomesticos         206
# Bateria                   instrumentos musicais    203
# Cama king                 moveis                   201
# Name: Produto, dtype: int64

# %%
todas_lojas = pd.concat([loja, loja2, loja3, loja4])
produtos_por_venda = todas_lojas.groupby(['Produto', 'Categoria do Produto'])['Produto'].count().sort_values(ascending=False)
produtos_por_venda.tail(5)
# Out:
# Produto                      Categoria do Produto
# Ciência de dados com python  livros                   166
# Guitarra                     instrumentos musicais    165
# Mochila                      esporte e lazer          163
# Headset                      eletronicos              158
# Celular ABXY                 eletronicos              157
# Name: Produto, dtype: int64

# %% [markdown]
# ##5. Frete Médio por Loja

# %%
frete_medio = loja['Frete'].mean()
frete_medio.round(2)
# Out:
# np.float64(34.69)

# %%
frete_medio = loja2['Frete'].mean()
frete_medio.round(2)
# Out:
# np.float64(33.62)

# %%
frete_medio = loja3['Frete'].mean()
frete_medio.round(2)
# Out:
# np.float64(33.07)

# %%
frete_medio = loja4['Frete'].mean()
frete_medio.round(2)
# Out:
# np.float64(31.28)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cálculo das médias
media1 = loja['Frete'].mean()
media2 = loja2['Frete'].mean()
media3 = loja3['Frete'].mean()
media4 = loja4['Frete'].mean()

# Criar DataFrame com as médias
df_medias = pd.DataFrame({
    'Loja': ['loja', 'loja2', 'loja3', 'loja4'],
    'Média Avaliação': [media1, media2, media3, media4]
})

# Gráfico de Pizza
plt.figure(figsize=(7,7))
plt.pie(
    df_medias['Média Avaliação'],
    labels=df_medias['Loja'],
    autopct='%1.2f%%',
    startangle=90
)
plt.title('Distribuição das Médias de Frete por Loja')
plt.show()

# %%
loja_metrics = {
    'loja 1': {
        'Faturamento': faturametento_total,
        'Avaliação Média': loja['Avaliação da compra'].mean().round(2),
        'Frete Médio': loja['Frete'].mean().round(2),
        'Produtos Mais Vendidos': loja.groupby(['Produto', 'Categoria do Produto'])['Produto'].count().sort_values(ascending=False).head(5).to_dict(),
        'Produtos Menos Vendidos': loja.groupby(['Produto', 'Categoria do Produto'])['Produto'].count().sort_values(ascending=False).tail(5).to_dict()
    },
    'loja 2': {
        'Faturamento': faturametento_total2,
        'Avaliação Média': loja2['Avaliação da compra'].mean().round(2),
        'Frete Médio': loja2['Frete'].mean().round(2),
        'Produtos Mais Vendidos': loja2.groupby(['Produto', 'Categoria do Produto'])['Produto'].count().sort_values(ascending=False).head(5).to_dict(),
        'Produtos Menos Vendidos': loja2.groupby(['Produto', 'Categoria do Produto'])['Produto'].count().sort_values(ascending=False).tail(5).to_dict()
    },
    'loja 3': {
        'Faturamento': faturametento_total3,
        'Avaliação Média': loja3['Avaliação da compra'].mean().round(2),
        'Frete Médio': loja3['Frete'].mean().round(2),
        'Produtos Mais Vendidos': loja3.groupby(['Produto', 'Categoria do Produto'])['Produto'].count().sort_values(ascending=False).head(5).to_dict(),
        'Produtos Menos Vendidos': loja3.groupby(['Produto', 'Categoria do Produto'])['Produto'].count().sort_values(ascending=False).tail(5).to_dict()
    },
    'loja 4': {
        'Faturamento': faturametento_total4,
        'Avaliação Média': loja4['Avaliação da compra'].mean().round(2),
        'Frete Médio': loja4['Frete'].mean().round(2),
        'Produtos Mais Vendidos': loja4.groupby(['Produto', 'Categoria do Produto'])['Produto'].count().sort_values(ascending=False).head(5).to_dict(),
        'Produtos Menos Vendidos': loja4.groupby(['Produto', 'Categoria do Produto'])['Produto'].count().sort_values(ascending=False).tail(5).to_dict()
    }
}

lojas_resumo = pd.DataFrame(loja_metrics).T
display(lojas_resumo)
# Out:
#        Faturamento Avaliação Média Frete Médio  \
# loja 1  1534509.12            3.98       34.69
# loja 2  1488459.06            4.04       33.62
# loja 3  1464025.03            4.05       33.07
# loja 4  1384497.58             4.0       31.28
#
#                                    Produtos Mais Vendidos  \
# loja 1  {('TV Led UHD 4K', 'eletronicos'): 60, ('Micro...
# loja 2  {('Iniciando em programação', 'livros'): 65, (...
# loja 3  {('Kit banquetas', 'moveis'): 57, ('Mesa de ja...
# loja 4  {('Cama box', 'moveis'): 62, ('Faqueiro', 'uti...
#
#                                   Produtos Menos Vendidos
# loja 1  {('Ciência de dados com python', 'livros'): 39...
# loja 2  {('Fone de ouvido', 'eletronicos'): 37, ('Polt...
# loja 3  {('Copo térmico', 'esporte e lazer'): 38, ('Mi...
# loja 4  {('Geladeira', 'eletrodomesticos'): 38, ('Lava...

# %% [markdown]
# ## Relatório

# %% [markdown]
# A pedido do Senhor João, realizamos uma análise completa de desempenho das 4 lojas da rede Alura Store, utilizando dados de:
#
# Faturamento total
#
# Média das avaliações dos clientes
#
# Indicadores complementares (frete)
#
# Com base nesses dados, o objetivo é identificar qual loja apresenta o pior desempenho operacional e deve ser fechada para que o Senhor João possa direcionar recursos para um novo empreendimento.

# %%
display(lojas_resumo)
# Out:
#        Faturamento Avaliação Média Frete Médio  \
# loja 1  1534509.12            3.98       34.69
# loja 2  1488459.06            4.04       33.62
# loja 3  1464025.03            4.05       33.07
# loja 4  1384497.58             4.0       31.28
#
#                                    Produtos Mais Vendidos  \
# loja 1  {('TV Led UHD 4K', 'eletronicos'): 60, ('Micro...
# loja 2  {('Iniciando em programação', 'livros'): 65, (...
# loja 3  {('Kit banquetas', 'moveis'): 57, ('Mesa de ja...
# loja 4  {('Cama box', 'moveis'): 62, ('Faqueiro', 'uti...
#
#                                   Produtos Menos Vendidos
# loja 1  {('Ciência de dados com python', 'livros'): 39...
# loja 2  {('Fone de ouvido', 'eletronicos'): 37, ('Polt...
# loja 3  {('Copo térmico', 'esporte e lazer'): 38, ('Mi...
# loja 4  {('Geladeira', 'eletrodomesticos'): 38, ('Lava...

# %% [markdown]
# ##1.Análise do Faturamento
#
# Segundo o gráfico enviado (Faturamento por loja):
#
#
# ![grafico de fatuyramento.png](data:image/png;base64,...)
#
# Loja 1: maior faturamento
#
# Loja 2: forte desempenho
#
# Loja 3: desempenho sólido
#
# Loja 4: menor faturamento entre as quatro unidades
#
# ✅ Conclusão parcial: A Loja 4 se destaca negativamente por gerar a menor receita, indicando baixa eficiência comercial.

# %% [markdown]
# ##2. Análise da Média das Avaliações
#
# Pelos graficos, as médias aproximadas foram:
# ![grafico d e media.png](data:image/png;base64,...)
#
# Loja	Média de Avaliação
#
# Loja 1	= 3.98
#
# Loja 2	= 4.04
#
# Loja 3	= 4.05
#
# Loja 4	= 3.99
#
# Loja 3 é a mais eficiente em satisfação do cliente.
#
# Loja 1 e Loja 4 são as menos eficientes (ambas com média abaixo de 4).

# %% [markdown]
# ##3. Distribuição das Médias
#
# A pizza representa a participação média dos custos de frete de cada loja em relação ao total das quatro.
# Os percentuais indicam:
#
# ![grafico de frete certo.png](data:image/png;base64,...)
#
# Loja 1: 26.15%
#
# Loja 2: 25.34%
#
# Loja 3: 24.93%
#
# Loja 4: 23.58%
#
# o menor custo médio de frete entre as lojas
#
# Isso está compatível com o fato de que a Loja 4 também tem menor número de vendas (menor faturamento).
# Quando uma loja vende menos, o frete total dividido pela quantidade de pedidos tende a gerar uma participação menor na comparação geral.

# %% [markdown]
# Recomendação Final
# **➡️ A Loja que o Senhor João deve fechar é:
# ✅ LOJA 4
# Justificativas baseadas em dados:
#
# Menor faturamento: impacto direto na receita da rede.
#
# Pior avaliação e menor satisfação do cliente: risco de danos à marca.
#
# Menor contribuição relativa no desempenho geral.
#
# Eficiência operacional baixa: reduz margens e aumenta custos.
#
# #Conclusão :
# Encerrar a Loja 4 é a decisão mais racional do ponto de vista financeiro e operacional. A economia gerada com o fechamento, somada à realocação de recursos para o novo empreendimento, maximizará o retorno do investimento e fortalecerá a performance global da Alura Store.
